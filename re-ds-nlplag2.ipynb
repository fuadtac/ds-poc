# %% [markdown]
# # Traing a Model for Sales Forecasting of NLP
# ### Training and Testing with XGBoost ML Model

# %% [markdown]
# ### Installing Libraries

# %%
#installing packages
# !pip install pyodbc pandas seaborn  matplotlib numpy xgboost scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyodbc in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (5.2.0)
# Requirement already satisfied: pandas in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (2.3.3)
# Requirement already satisfied: seaborn in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (3.10.6)
# Requirement already satisfied: numpy in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (2.2.6)
# Requirement already satisfied: xgboost in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (3.0.5)
# Requirement already satisfied: scikit-learn in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (1.7.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: scipy in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from xgboost) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\fuad.jamali\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importing Libraries

# %%
#importing libraries
import pyodbc
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
from xgboost import plot_importance, plot_tree
import joblib
import os

# %% [markdown]
# ### Connecting to Database

# %%
# Define connection parameters
server = 'rebates-mssql-2019-2-dev.con8g81q8rff.us-east-1.rds.amazonaws.com'  # e.g., 'your-db-name.region.rds.amazonaws.com'
database = 'dev-rebate-merit'

# Get credentials from environment
username = os.getenv("DB_USER_DEV")
password = os.getenv("DB_PASSWORD_DEV")

# override for local testing
#username = '****'
#password = '***'
driver = '{ODBC Driver 17 for SQL Server}'  # Make sure this driver is installed

# %%
# Create connection string
connection_string = f'''
    DRIVER={driver};
    SERVER={server};
    DATABASE={database};
    UID={username};
    PWD={password};
    Encrypt=no;
    TrustServerCertificate=yes;
    Connection Timeout=30;
'''

try:
    conn = pyodbc.connect(connection_string)
    print("✅ Connection successful!")
except Exception as e:
    print("❌ Connection failed:", e)
# Out:
# ✅ Connection successful!

# %% [markdown]
# ### Retrieving Data form Database

# %%
# Defining SQL query
df_sql = pd.DataFrame()
query = '''
				WITH NLP_Sales AS 
					(
						SELECT SID.[orderdate] AS [date], 
								SID.PayeeCustomerAccount AS [customer], 
								SUM(SID.InvAmt) AS [sales], 
								COUNT(SID.productcode) AS [no_of_products]
						FROM SalesInvoiceDetail SID
						JOIN batch B ON SID.batchid = B.id 
							AND B.schemeid IN (6918,6401)
						JOIN CustomerMaster CM on SID.PayeeCustomerAccount = CM.CustomerAccount
							AND BatchNo IN (15)
							AND ((b.BatchTypeId = 1 AND MonthlyPaymentApplicable = 1))
						--OR (b.BatchTypeId = 2 and MonthlyPaymentApplicable = 0))
							AND SID.salesinvoicetypeid IN (1, 12)
							AND excluded = 0 AND  category = 'Nobivac Vaccines'
						--WHERE SID.CustomerAccount = '0000008687'
						GROUP BY sid.[orderdate], SID.PayeeCustomerAccount 
                
					)

				SELECT * FROM NLP_Sales
				ORDER BY customer,date


'''

# Execute and store results in a pandas DataFrame
try:
    df_sql = pd.read_sql(query, conn)
    print("✅ Query executed and data loaded into DataFrame.")
    display(df_sql.head())  # Show first few rows
except Exception as e:
    print("❌ Failed to execute query:", e)
# Out:
# C:\Users\Fuad.Jamali\AppData\Local\Temp\ipykernel_7424\3432925708.py:32: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_sql = pd.read_sql(query, conn)
# ✅ Query executed and data loaded into DataFrame.
#         date    customer    sales  no_of_products
# 0 2023-01-02  0000008687   982.75               3
# 1 2023-01-03  0000008687  2753.00               9
# 2 2023-01-04  0000008687  1456.26               4
# 3 2023-01-05  0000008687  1147.25               4
# 4 2023-01-06  0000008687   552.75               1

# %%
df_sql.tail()
# Out:
#            date    customer     sales  no_of_products
# 6581 2024-12-18  0010741041  20159.75               3
# 6582 2024-12-23  0010741041   5986.08               1
# 6583 2024-12-27  0010741041   1416.00               2
# 6584 2024-12-30  0010741041    765.40               1
# 6585 2024-12-31  0010741041  30380.02               8

# %%
df_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6586 entries, 0 to 6585
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6586 non-null   datetime64[ns]
#  1   customer        6586 non-null   object
#  2   sales           6586 non-null   float64
#  3   no_of_products  6586 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 205.9+ KB

# %% [markdown]
# ### Importing Sales Data from csv file

# %%
# @title Importing Sales Data (CSV)
#loading CSV file into df
#df = pd.read_csv('NLP_2023_2024_EOY_Daily_Sales.csv',header=None,names=['Date','Customer','Sales'])
#df.head()

# %% [markdown]
# # 🧭 Descriptive Analysis Steps

# %%
# assigning df_sql to df 
df = df_sql.copy(deep=True)

# %% [markdown]
# ## Ecploring Data Structure

# %%
# @title Checking Shape of Data
df.shape
# Out:
# (6586, 4)

# %%
# @title View column names and data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6586 entries, 0 to 6585
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6586 non-null   datetime64[ns]
#  1   customer        6586 non-null   object
#  2   sales           6586 non-null   float64
#  3   no_of_products  6586 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 205.9+ KB

# %%
# @title Summary Statistics - Numerical Column
df.describe()
# Out:
#                                 date          sales  no_of_products
# count                           6586    6586.000000     6586.000000
# mean   2024-02-20 08:21:47.500759040    4772.120821        3.088521
# min              2023-01-01 00:00:00  -18689.250000        1.000000
# 25%              2023-08-25 00:00:00     712.000000        1.000000
# 50%              2024-04-08 00:00:00    1599.125000        2.000000
# 75%              2024-08-14 00:00:00    3697.562500        4.000000
# max              2024-12-31 00:00:00  553910.880000       49.000000
# std                              NaN   19806.574959        3.263646

# %%
# @title Summary Statistics - Categorial Values
df['customer'].value_counts()
# Out:
# customer
# 0010366334    499
# 0010013160    396
# 0010231535    268
# 0010044204    201
# 0010012882    156
#              ...
# 0010165089      5
# 0010011396      4
# 0010057933      3
# 0010129790      1
# 0010117531      1
# Name: count, Length: 102, dtype: int64

# %% [markdown]
# ## Data Type Conversion

# %%
# @title Convert Date field to DateTime Type
df['date'] = pd.to_datetime(df['date'])
df['customer'] = pd.to_numeric(df['customer'])
#df.set_index('date', inplace=True)
df.head()
# Out:
#         date  customer    sales  no_of_products
# 0 2023-01-02      8687   982.75               3
# 1 2023-01-03      8687  2753.00               9
# 2 2023-01-04      8687  1456.26               4
# 3 2023-01-05      8687  1147.25               4
# 4 2023-01-06      8687   552.75               1

# %%
# Checking for Missing/NULL Values
df.isnull().sum()
# Out:
# date              0
# customer          0
# sales             0
# no_of_products    0
# dtype: int64

# %%
# Cheking Duplicates Values
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##  Data Distribution Analysis

# %%
# @title Histrogams of Sales

plt.figure()
plt.hist(data=df,x='sales')
plt.show()

# %%
# @title Boxplot of Sales

plt.figure()
sns.boxplot(data=df['sales'])
plt.show()

# %%
# @title Correlation Analysis
df.corr()
# Out:
#                     date  customer     sales  no_of_products
# date            1.000000  0.207449 -0.024260        0.063218
# customer        0.207449  1.000000  0.028538       -0.013639
# sales          -0.024260  0.028538  1.000000        0.301551
# no_of_products  0.063218 -0.013639  0.301551        1.000000

# %%
#df.reset_index(inplace=True)
df.head()
# Out:
#         date  customer    sales  no_of_products
# 0 2023-01-02      8687   982.75               3
# 1 2023-01-03      8687  2753.00               9
# 2 2023-01-04      8687  1456.26               4
# 3 2023-01-05      8687  1147.25               4
# 4 2023-01-06      8687   552.75               1

# %% [markdown]
# ## Apply Log Tranformation to eliminate outliers

# %%
# Log transform sales_amount
df['sales_log'] = df['sales'].apply(lambda x: np.log(x) if x > 0 else np.nan)

# %%
# Drop rows with NaN in target
df = df.dropna(subset=['sales_log'])

# %%
# @title Histrogams of Sales after applying Log Transformation

plt.figure()
plt.hist(data=df,x='sales_log')
plt.show()

# %%
# @title Boxplot of Sales after Log Transformation

plt.figure()
sns.boxplot(data=df['sales_log'])
plt.show()

# %%
# Creating funciton to add Time Series Features in given Data Frame
def add_time_series_features(df, label=None):
    """
    Creates time series features from datetime index
    """
    df.reset_index(inplace=True)
    #df['year_month'] = df['date'].dt.to_period('M')
    #df['year_month'] = df['date'].dt.to_timestamp()
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    #df['quarter'] = df['date'].dt.quarter
    #df['dayofweek'] = df['date'].dt.dayofweek
    #df['dayofyear'] = df['date'].dt.dayofyear
    #df['dayofmonth'] = df['date'].dt.day
    df.set_index('date', inplace=True)
    df.drop('index',axis=1,inplace=True)
    #X = df[['dayofweek','quarter','month','year',
           #'dayofyear','dayofmonth']]
    #if label:
     #   y = df[label]
      #  return X, y
    return df

# %%
# Adding Time Series Features in data frame
df = add_time_series_features(df,None)

# %%
df.head()
# Out:
#             customer    sales  no_of_products  sales_log  year  month
# date
# 2023-01-02      8687   982.75               3   6.890355  2023      1
# 2023-01-03      8687  2753.00               9   7.920447  2023      1
# 2023-01-04      8687  1456.26               4   7.283627  2023      1
# 2023-01-05      8687  1147.25               4   7.045123  2023      1
# 2023-01-06      8687   552.75               1   6.314906  2023      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6504 entries, 2023-01-02 to 2024-12-31
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer        6504 non-null   int64
#  1   sales           6504 non-null   float64
#  2   no_of_products  6504 non-null   int64
#  3   sales_log       6504 non-null   float64
#  4   year            6504 non-null   int32
#  5   month           6504 non-null   int32
# dtypes: float64(2), int32(2), int64(2)
# memory usage: 304.9 KB

# %%
def add_lag_features (df):
    df['lag_1'] = df.groupby('customer')['sales'].shift(1)
    df['lag_2'] = df.groupby('customer')['sales'].shift(2)
    #df['lag_3'] = df.groupby('customer')['sales'].shift(3)
    df['rolling_mean_2'] = df.groupby('customer')['sales'].rolling(window=2).mean().iloc[-1]
    return df

# %%
df = add_lag_features(df)

# %%
df.head()
# Out:
#             customer    sales  no_of_products  sales_log  year  month  \
# date
# 2023-01-02      8687   982.75               3   6.890355  2023      1
# 2023-01-03      8687  2753.00               9   7.920447  2023      1
# 2023-01-04      8687  1456.26               4   7.283627  2023      1
# 2023-01-05      8687  1147.25               4   7.045123  2023      1
# 2023-01-06      8687   552.75               1   6.314906  2023      1
#
#               lag_1    lag_2  rolling_mean_2
# date
# 2023-01-02      NaN      NaN        15572.71
# 2023-01-03   982.75      NaN        15572.71
# 2023-01-04  2753.00   982.75        15572.71
# 2023-01-05  1456.26  2753.00        15572.71
# 2023-01-06  1147.25  1456.26        15572.71

# %%
df.count()
# Out:
# customer          6504
# sales             6504
# no_of_products    6504
# sales_log         6504
# year              6504
# month             6504
# lag_1             6402
# lag_2             6302
# rolling_mean_2    6504
# dtype: int64

# %% [markdown]
# # Train a model using XGBoost ML

# %%
# split train and test data from df
split_date = '2024-10-01'
train_df = df.loc[df.index <= split_date].copy()
test_df = df.loc[df.index > split_date].copy()

# %%
x_train = train_df.drop(columns=['sales','sales_log'])
y_train = train_df['sales_log']
x_test = test_df.drop(columns=['sales','sales_log'])
y_test = test_df['sales_log']

# %%
x_train.head()
# Out:
#             customer  no_of_products  year  month    lag_1    lag_2  \
# date
# 2023-01-02      8687               3  2023      1      NaN      NaN
# 2023-01-03      8687               9  2023      1   982.75      NaN
# 2023-01-04      8687               4  2023      1  2753.00   982.75
# 2023-01-05      8687               4  2023      1  1456.26  2753.00
# 2023-01-06      8687               1  2023      1  1147.25  1456.26
#
#             rolling_mean_2
# date
# 2023-01-02        15572.71
# 2023-01-03        15572.71
# 2023-01-04        15572.71
# 2023-01-05        15572.71
# 2023-01-06        15572.71

# %%
y_train.head()
# Out:
# date
# 2023-01-02    6.890355
# 2023-01-03    7.920447
# 2023-01-04    7.283627
# 2023-01-05    7.045123
# 2023-01-06    6.314906
# Name: sales_log, dtype: float64

# %%
x_test.head()
# Out:
#             customer  no_of_products  year  month   lag_1   lag_2  \
# date
# 2024-10-08  10000863               3  2024     10  1795.0  4302.5
# 2024-10-09  10000863               6  2024     10  2555.5  1795.0
# 2024-10-21  10000863               3  2024     10  8770.0  2555.5
# 2024-10-30  10000863               1  2024     10  3107.5  8770.0
# 2024-11-05  10000863               1  2024     11   853.0  3107.5
#
#             rolling_mean_2
# date
# 2024-10-08        15572.71
# 2024-10-09        15572.71
# 2024-10-21        15572.71
# 2024-10-30        15572.71
# 2024-11-05        15572.71

# %%
print(y_test.head())
# Out:
# date
# 2024-10-08    7.846003
# 2024-10-09    9.079092
# 2024-10-21    8.041574
# 2024-10-30    6.748760
# 2024-11-05    8.058011
# Name: sales_log, dtype: float64

# %% [markdown]
# ### Feature Importances
# <p> Feature importance is a great way to get a general idea about which features the model is relying on most to make the prediction. This is a metric that simply sums up how many times each feature is split on.
#
# We can see that the day of week was most commonly used to split trees, while day of the month and year came in next. Quarter has low importance due to the fact that it could be created by different dayofyear splits. <p>

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

# Define the parameter grid to search
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7]
    
}

# Initialize GridSearchCV
grid_search = GridSearchCV(estimator=XGBRegressor(eval_metric="mae"),
                           param_grid=param_grid,
                           scoring='neg_mean_absolute_error', # Use negative MAE for optimization
                           cv=3, # Cross-validation folds
                           verbose=2,
                           n_jobs=-1
                           ) # Use all available cores

# Fit the grid search to the training data
grid_search.fit(x_train, y_train)

# Print the best parameters and best score
print("Best parameters found: ", grid_search.best_params_)
print("Best negative MAE found: ", grid_search.best_score_)

# Update the regressor with the best parameters
reg_tuned = grid_search.best_estimator_
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Best parameters found:  {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# Best negative MAE found:  -0.7567598477117029

# %%
_ = plot_importance(reg_tuned, height=0.9)

# %%
test_df['sales_prediction'] = reg_tuned.predict(x_test)
df_all = pd.concat([test_df,train_df], sort=False)

# %%
df4 = test_df[test_df['customer'] == 10000863]

df4
# Out:
#             customer     sales  no_of_products  sales_log  year  month  \
# date
# 2024-10-08  10000863   2555.50               3   7.846003  2024     10
# 2024-10-09  10000863   8770.00               6   9.079092  2024     10
# 2024-10-21  10000863   3107.50               3   8.041574  2024     10
# 2024-10-30  10000863    853.00               1   6.748760  2024     10
# 2024-11-05  10000863   3159.00               1   8.058011  2024     11
# 2024-11-11  10000863   2151.00               3   7.673688  2024     11
# 2024-11-21  10000863   3124.00               3   8.046870  2024     11
# 2024-11-22  10000863   5365.25               5   8.587698  2024     11
# 2024-12-05  10000863   1227.00               2   7.112327  2024     12
# 2024-12-13  10000863   6804.50               5   8.825339  2024     12
# 2024-12-18  10000863   4158.00               1   8.332789  2024     12
# 2024-12-26  10000863  58500.50              12  10.976791  2024     12
# 2024-12-27  10000863    352.50               3   5.865051  2024     12
#
#                lag_1    lag_2  rolling_mean_2  sales_prediction
# date
# 2024-10-08   1795.00  4302.50        15572.71          7.710668
# 2024-10-09   2555.50  1795.00        15572.71          7.971888
# 2024-10-21   8770.00  2555.50        15572.71          7.929920
# 2024-10-30   3107.50  8770.00        15572.71          7.123395
# 2024-11-05    853.00  3107.50        15572.71          6.969713
# 2024-11-11   3159.00   853.00        15572.71          7.565475
# 2024-11-21   2151.00  3159.00        15572.71          7.570025
# 2024-11-22   3124.00  2151.00        15572.71          7.800360
# 2024-12-05   5365.25  3124.00        15572.71          7.506856
# 2024-12-13   1227.00  5365.25        15572.71          7.964892
# 2024-12-18   6804.50  1227.00        15572.71          7.055145
# 2024-12-26   4158.00  6804.50        15572.71          8.528739
# 2024-12-27  58500.50  4158.00        15572.71          8.238592

# %%
test_df.head()
# Out:
#             customer   sales  no_of_products  sales_log  year  month   lag_1  \
# date
# 2024-10-08  10000863  2555.5               3   7.846003  2024     10  1795.0
# 2024-10-09  10000863  8770.0               6   9.079092  2024     10  2555.5
# 2024-10-21  10000863  3107.5               3   8.041574  2024     10  8770.0
# 2024-10-30  10000863   853.0               1   6.748760  2024     10  3107.5
# 2024-11-05  10000863  3159.0               1   8.058011  2024     11   853.0
#
#              lag_2  rolling_mean_2  sales_prediction
# date
# 2024-10-08  4302.5        15572.71          7.710668
# 2024-10-09  1795.0        15572.71          7.971888
# 2024-10-21  2555.5        15572.71          7.929920
# 2024-10-30  8770.0        15572.71          7.123395
# 2024-11-05  3107.5        15572.71          6.969713

# %%
_ = df_all[['sales','sales_prediction']].plot(figsize=(15, 5))
#plt.title('Sales and Tuned Model Predictions Over Time')
plt.xlabel('date')
plt.ylabel('sales')
plt.show()

# %%
# Train the model
model = XGBRegressor(n_estimators=100, max_depth=3, learning_rate=0.1, random_state=42)
model.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Predict future sales
predictions = model.predict(x_test)

# %%
# Evaluate performance
mae = mean_absolute_error(y_test, predictions)
rmse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"R-squared (R²): {r2:.2f}")
# Out:
# Mean Absolute Error (MAE): 0.53
# Root Mean Squared Error (RMSE): 0.48
# R-squared (R²): 0.62

# %%
# Bias and variance
bias_squared = (np.mean(predictions) - np.mean(y_test)) ** 2
variance = np.var(predictions)
mse = mean_squared_error(y_test, predictions)


# Print results
print(f"Bias²: {bias_squared:.2f}")
print(f"Variance: {variance:.2f}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Bias²: 0.01
# Variance: 0.99
# Mean Squared Error (MSE): 0.48

# %%
plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
# Plot actual vs predicted sales
plt.figure(figsize=(12, 6))
plt.plot(y_test.index, y_test, label='Actual Sales', marker='o')
plt.plot(y_test.index, predictions, label='Predicted Sales', marker='x')
#plt.title('Actual vs Predicted Sales')
plt.xlabel('date')
plt.ylabel('sales_log')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot distributions
plt.figure(figsize=(8, 5))
sns.kdeplot(y_test, label='Actual', fill=True)
sns.kdeplot(predictions, label='Predicted', fill=True)
plt.title('Distribution of Actual vs Predicted Values')
plt.xlabel('Target Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot histogram comparison
plt.figure(figsize=(10, 6))
plt.hist(y_test, bins=30, alpha=0.6, label='Actual Values', color='blue', edgecolor='black')
plt.hist(predictions, bins=30, alpha=0.6, label='Predicted Values', color='orange', edgecolor='black')
plt.title('Distribution of Actual vs Predicted Values')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
